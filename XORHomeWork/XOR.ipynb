# %%
import torch
import torch.nn as nn 
import torch.optim as optim

# %%
X = torch.tensor([[-1, -1], [-1, 1], [1, -1], [1, 1]], dtype=torch.float32)
Y = torch.tensor([0, 1, 1, 0], dtype=torch.float32)

# %%
class XORNet(nn.Module):
    def __init__(self):
        super(XORNet, self).__init__()
        self.fc1 = nn.Linear(2, 4)  
        self.fc2 = nn.Linear(4, 1)  

    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        return x

# %%
net = XORNet()
criterion = nn.MSELoss()
optimizer = optim.SGD(net.parameters(), lr=0.1)

# %%
for epoch in range(100000):  
    optimizer.zero_grad()  
    outputs = net(X)
    loss = criterion(outputs, Y.view(-1, 1)) 
    loss.backward() 
    optimizer.step() 

    if epoch % 1000 == 0:
        print(f'Эпоха {epoch}, потеря: {loss.item()}')
# Out:
# Эпоха 0, потеря: 0.26090991497039795
# Эпоха 1000, потеря: 0.24700939655303955
# Эпоха 2000, потеря: 0.2259925901889801
# Эпоха 3000, потеря: 0.1555517166852951
# Эпоха 4000, потеря: 0.05459880083799362
# Эпоха 5000, потеря: 0.020954366773366928
# Эпоха 6000, потеря: 0.01128310151398182
# Эпоха 7000, потеря: 0.007294265553355217
# Эпоха 8000, потеря: 0.005219356156885624
# Эпоха 9000, потеря: 0.003981347195804119
# Эпоха 10000, потеря: 0.003174377838149667
# Эпоха 11000, потеря: 0.0026146681047976017
# Эпоха 12000, потеря: 0.002207996789366007
# Эпоха 13000, потеря: 0.0019016097066923976
# Эпоха 14000, потеря: 0.0016639262903481722
# Эпоха 15000, потеря: 0.0014750510454177856
# Эпоха 16000, потеря: 0.0013219115789979696
# Эпоха 17000, потеря: 0.0011956088710576296
# Эпоха 18000, потеря: 0.0010898952605202794
# Эпоха 19000, потеря: 0.0010002973722293973
# Эпоха 20000, потеря: 0.000923492421861738
# Эпоха 21000, потеря: 0.0008570287609472871
# Эпоха 22000, потеря: 0.0007989945588633418
# Эпоха 23000, потеря: 0.0007479411433450878
# Эпоха 24000, потеря: 0.0007027117535471916
# Эпоха 25000, потеря: 0.0006623860099352896
# Эпоха 26000, потеря: 0.0006262350361794233
# Эпоха 27000, потеря: 0.000593654636759311
# Эпоха 28000, потеря: 0.0005641552852466702
# Эпоха 29000, потеря: 0.0005373297026380897
# Эпоха 30000, потеря: 0.0005128401680849493
# Эпоха 31000, потеря: 0.0004904011730104685
# Эпоха 32000, потеря: 0.00046977028250694275
# Эпоха 33000, потеря: 0.00045074126683175564
# Эпоха 34000, потеря: 0.0004331461386755109
# Эпоха 35000, потеря: 0.0004168188897892833
# Эпоха 36000, потеря: 0.0004016346065327525
# Эпоха 37000, потеря: 0.0003874810063280165
# Эпоха 38000, потеря: 0.0003742726403288543
# Эпоха 39000, потеря: 0.00036189297679811716
# Эпоха 40000, потеря: 0.00035029405262321234
# Эпоха 41000, потеря: 0.00033937502303160727
# Эпоха 42000, потеря: 0.0003291149332653731
# Эпоха 43000, потеря: 0.00031943185604177415
# Эпоха 44000, потеря: 0.00031028036028146744
# Эпоха 45000, потеря: 0.0003016315749846399
# Эпоха 46000, потеря: 0.00029344018548727036
# Эпоха 47000, потеря: 0.0002856537466868758
# Эпоха 48000, потеря: 0.0002782783121801913
# Эпоха 49000, потеря: 0.00027127182693220675
# Эпоха 50000, потеря: 0.0002645607746671885
# Эпоха 51000, потеря: 0.0002582113374955952
# Эпоха 52000, потеря: 0.00025212514447048306
# Эпоха 53000, потеря: 0.000246312003582716
# Эпоха 54000, потеря: 0.00024077972921077162
# Эпоха 55000, потеря: 0.00023545512522105128
# Эпоха 56000, потеря: 0.00023037890787236392
# Эпоха 57000, потеря: 0.00022548119886778295
# Эпоха 58000, потеря: 0.0002208146615885198
# Эпоха 59000, потеря: 0.00021632805874105543
# Эпоха 60000, потеря: 0.0002120203571394086
# Эпоха 61000, потеря: 0.0002078320103464648
# Эпоха 62000, потеря: 0.00020385517564136535
# Эпоха 63000, потеря: 0.00020002786186523736
# Эпоха 64000, потеря: 0.00019630073802545667
# Эпоха 65000, потеря: 0.00019271619385108352
# Эпоха 66000, потеря: 0.000189262063940987
# Эпоха 67000, потеря: 0.00018594048742670566
# Эпоха 68000, потеря: 0.00018274289323017
# Эпоха 69000, потеря: 0.00017962069250643253
# Эпоха 70000, потеря: 0.00017658974684309214
# Эпоха 71000, потеря: 0.00017368576664011925
# Эпоха 72000, потеря: 0.00017086401931010187
# Эпоха 73000, потеря: 0.00016813910042401403
# Эпоха 74000, потеря: 0.00016549717111047357
# Эпоха 75000, потеря: 0.00016292836517095566
# Эпоха 76000, потеря: 0.00016044816584326327
# Эпоха 77000, потеря: 0.0001580287207616493
# Эпоха 78000, потеря: 0.00015568725939374417
# Эпоха 79000, потеря: 0.0001533974427729845
# Эпоха 80000, потеря: 0.00015117759176064283
# Эпоха 81000, потеря: 0.00014903694682288915
# Эпоха 82000, потеря: 0.00014695250138174742
# Эпоха 83000, потеря: 0.00014494068454951048
# Эпоха 84000, потеря: 0.00014296869630925357
# Эпоха 85000, потеря: 0.00014102528803050518
# Эпоха 86000, потеря: 0.0001391333353240043
# Эпоха 87000, потеря: 0.00013729737838730216
# Эпоха 88000, потеря: 0.00013551334268413484
# Эпоха 89000, потеря: 0.0001337808498647064
# Эпоха 90000, потеря: 0.00013208997552283108
# Эпоха 91000, потеря: 0.00013044006482232362
# Эпоха 92000, потеря: 0.00012883091403637081
# Эпоха 93000, потеря: 0.00012728061119560152
# Эпоха 94000, потеря: 0.0001257636322407052
# Эпоха 95000, потеря: 0.00012426759349182248
# Эпоха 96000, потеря: 0.0001227911125170067
# Эпоха 97000, потеря: 0.00012134003918617964
# Эпоха 98000, потеря: 0.00011991497012786567
# Эпоха 99000, потеря: 0.0001185180590255186

# %%
with torch.no_grad():
    test_data = torch.tensor([[-1, -1], [-1, 1], [1, -1], [1, 1]], dtype=torch.float32)
    predictions = net(test_data)
    for i, prediction in enumerate(predictions):
        print(f'Вход: {test_data[i].tolist()}, Выход: {round(prediction.item())}')
# Out:
# Вход: [-1.0, -1.0], Выход: 0
# Вход: [-1.0, 1.0], Выход: 1
# Вход: [1.0, -1.0], Выход: 1
# Вход: [1.0, 1.0], Выход: 0
