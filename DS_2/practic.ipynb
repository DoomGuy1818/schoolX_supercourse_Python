# %%
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv('python_task_dataset.csv')
data.head(20)
# Out:
#     device_id device_type             datetime  ev_type adv_type  region_id  \
# 0      100001     android  2019-03-01 15:58:02        0    multi          2
# 1      100001     android  2019-03-01 17:13:53        0    multi          2
# 2      100002     android  2019-03-01 23:13:25        0    multi          2
# 3      100002     android  2019-03-01 23:25:06        0    multi          2
# 4      100003     android  2019-03-01 15:27:53        0    multi          1
# 5      100004     android  2019-03-01 15:31:17        0    multi          1
# 6      100005     android  2019-03-01 15:32:34        0    multi          1
# 7      100006     android  2019-03-01 15:32:38        0    multi          1
# 8      100006     android  2019-03-01 15:57:59        0    multi          1
# 9      100007     android  2019-03-01 15:33:10        0    multi          1
# 10     100007     android  2019-03-01 15:57:29        0    multi          1
# ...

# %%
appleUsers = data.loc[data['device_type'] == 'iphone']
print(appleUsers)
# Out:
# Empty DataFrame
# Columns: [device_id, device_type, datetime, ev_type, adv_type, region_id, age, gender]
# Index: []

# %%
genders = data['gender'].value_counts()
women = genders[2]
print(women)
# Out:
# 10440
